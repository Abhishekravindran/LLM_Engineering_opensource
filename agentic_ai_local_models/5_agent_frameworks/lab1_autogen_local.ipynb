# %% [markdown]
# # Week 5, Lab 1 — AutoGen on a local model

# %%
WEEK = 'Week 5'
LAB = 'Lab 1 — AutoGen local'

import sys
from pathlib import Path

def _course_root() -> Path:
    here = Path.cwd().resolve()
    for p in [here, *here.parents]:
        if (p / "shared" / "course_runtime.py").exists():
            return p
    for c in [
        here / "agentic_ai_local",
        Path("/content/agentic_ai_local"),
        Path("/content"),
    ]:
        if (c / "shared" / "course_runtime.py").exists():
            return c
    return here

ROOT = _course_root()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from shared.course_runtime import (
    detect_backend,
    print_banner,
    local_chat,
    calculator,
    lookup_fact,
    today_date,
    extract_json_object,
    parse_tool_call,
    openai_client_kwargs,
    get_langchain_llm,
    TOOL_SCHEMAS,
    MOCK_KB,
)

BACKEND = print_banner(WEEK, LAB)
print("If import failed, unzip/clone the WHOLE course folder (not a single notebook).")
# Out:
# Week 5 / Lab 1 — AutoGen local
# Backend: ollama
# Need Ollama running: `ollama serve` and `ollama pull llama3.2:1b`
# If import failed, unzip/clone the WHOLE course folder (not a single notebook).

# %%
cfg = openai_client_kwargs()
config_list = [{
    "model": cfg["model"],
    "base_url": cfg["base_url"],
    "api_key": cfg["api_key"],
    "price": [0, 0],
}]
llm_config = {"config_list": config_list, "temperature": 0.2, "timeout": 120}

import autogen

assistant = autogen.AssistantAgent(
    name="assistant",
    system_message="You are a concise tutor. 3 sentences max. Say TERMINATE when done.",
    llm_config=llm_config,
)
user = autogen.UserProxyAgent(
    name="user",
    human_input_mode="NEVER",
    max_consecutive_auto_reply=2,
    is_termination_msg=lambda m: m.get("content") and "TERMINATE" in m["content"],
    code_execution_config=False,
)
user.initiate_chat(assistant, message="Explain Langchain in 3 sentences for students.")
# Out:
# user (to assistant):
#
# Explain Langchain in 3 sentences for students.
#
# --------------------------------------------------------------------------------
# assistant (to user):
#
# LangChain is an open-source framework that allows developers to integrate language models into their applications, enabling more advanced AI interactions and functionalities. It provides tools like vector stores and APIs to manage data and model interactions efficiently. Students can use it to build chatbots, knowledge graphs, and other intelligent systems.
#
# --------------------------------------------------------------------------------
# user (to assistant):
#
#
#
# --------------------------------------------------------------------------------
# assistant (to user):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (09b86a5d-7bab-463a-bbf2-b09972cbb107): Termination message condition on agent 'user' met
# ChatResult(chat_id=37615779356897859309729171216567584714, chat_history=[{'content': 'Explain Langchain in 3 sentences for students.', 'role': 'assistant', 'name': 'user'}, {'content': 'LangChain is an open-source framework that allows developers to integrate language models into their applications, enabling more advanced AI interactions and functionalities. It provides tools like vector stores and APIs to manage data and model interactions efficiently. Students can use it to build chatbots, knowledge graphs, and other intelligent systems.', 'role': 'user', 'name': 'assistant'}, {'content': '', 'role': 'assistant', 'name': 'user'}, {'content': 'TERMINATE', 'role': 'user', 'name': 'assistant'}], summary='', cost={'usage_including_cached_inference': {'total_cost': 0.0, 'qwen2.5:3b': {'cost': 0.0, 'prompt_tokens': 151, 'completion_tokens': 64, 'total_tokens': 215}}, 'usage_excluding_cached_inference': {'total_cost': 0.0, 'qwen2.5:3b': {'cost': 0.0, 'prompt_tokens': 151, 'completion_tokens': 64, 'total_tokens': 215}}}, human_input=[])

# %% [markdown]
# **Next:** GroupChat.
