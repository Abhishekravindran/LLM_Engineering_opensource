# %% [markdown]
# # Week 3, Lab 2 — Role, goal, backstory

# %%
WEEK = 'Week 3'
LAB = 'Lab 2 — backstories'

import sys
from pathlib import Path

def _course_root() -> Path:
    here = Path.cwd().resolve()
    for p in [here, *here.parents]:
        if (p / "shared" / "course_runtime.py").exists():
            return p
    for c in [
        here / "agentic_ai_local",
        Path("/content/agentic_ai_local"),
        Path("/content"),
    ]:
        if (c / "shared" / "course_runtime.py").exists():
            return c
    return here

ROOT = _course_root()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from shared.course_runtime import (
    detect_backend,
    print_banner,
    local_chat,
    calculator,
    lookup_fact,
    today_date,
    extract_json_object,
    parse_tool_call,
    openai_client_kwargs,
    get_langchain_llm,
    TOOL_SCHEMAS,
    MOCK_KB,
)

BACKEND = print_banner(WEEK, LAB)
print("If import failed, unzip/clone the WHOLE course folder (not a single notebook).")
# Out:
# Week 3 / Lab 2 — backstories
# Backend: ollama
# Need Ollama running: `ollama serve` and `ollama pull llama3.2:1b`
# If import failed, unzip/clone the WHOLE course folder (not a single notebook).

# %%
cfg = openai_client_kwargs()
from crewai import LLM, Agent, Task, Crew, Process

# cfg
llm = LLM(
    model="ollama/qwen2.5:3b",
    base_url="http://localhost:11434/",
)
print("CrewAI LLM ->", cfg)
# Out:
# CrewAI LLM -> {'base_url': 'http://localhost:11434/v1', 'api_key': 'ollama', 'model': 'qwen2.5:3b'}

# %%
TOPIC = "Explain ReAct agents in 3 sentences."
backstories = {
    "professor": "A tenured CS professor who uses precise vocabulary.",
    "ta": "A friendly teaching assistant who uses analogies with cooking.",
    "skeptic": "An engineer who distrusts hype and always mentions failure modes.",
}

for label, story in backstories.items():
    agent = Agent(role="Explainer", goal="Help a student understand ReAct.", backstory=story, llm=llm, verbose=False)
    task = Task(description=TOPIC, expected_output="Exactly 3 sentences.", agent=agent)
    crew = Crew(agents=[agent], tasks=[task], verbose=False)
    print("====", label, "====")
    print(crew.kickoff())
    print()
# Out:
# ==== professor ====
# ReAct agents are a unique approach in AI that combines reactive learning with proactive planning. Reactive agents respond directly to inputs from their environment without maintaining an internal model of the world, whereas proactive agents predict future states based on past experiences and plan actions accordingly. By integrating both reactive and proactive strategies, ReAct agents achieve superior performance by leveraging the strengths of each, enabling them to adapt quickly in dynamic environments while also foreseeing potential outcomes for optimal decision-making.
#
# ==== ta ====
# ReAct agents are like well-trained chefs in an integrated kitchen. Just as each chef specializes in different cooking tasks - some are experts at sautéing vegetables, others excel at mixing dough - ReAct agents are designed to perform specific roles based on their training and data access. They learn from past interactions, much like how a seasoned chef remembers recipes for quick recall during a busy shift, allowing them to adapt and improve with every interaction in the kitchen of digital communication.
#
# ==== skeptic ====
# ReAct agents are designed to combine their reasoning capabilities with external data from the web or databases. They can process complex tasks by integrating logic-driven decision-making with real-time information gathering, potentially leading to more informed and contextually rich outputs. However, there is a risk of over-reliance on unreliable online resources, which could introduce inaccuracies or biases into their decisions. Therefore, it's crucial for developers to carefully vet the sources they connect these agents to, ensuring that the data they use is trustworthy and relevant to the task at hand.

# %% [markdown]
# Which knob matters more: backstory or goal? **Next:** sequential vs hierarchical.
